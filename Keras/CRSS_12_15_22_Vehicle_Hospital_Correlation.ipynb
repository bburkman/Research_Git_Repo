# %% [markdown]
# - CRSS where each sample corresponds to one person, not to one accident.
# - This one corresponds better to evaluating per phone.

# %%
# %%latex
# \tableofcontents
# Out:
# \tableofcontents

# %% [markdown]
# # Setup
# ## Import Libraries

# %%
import sys, copy, math, time

print ('Python version: {}'.format(sys.version))

from IPython.display import display, HTML

from collections import Counter

import numpy as np
print ('NumPy version: {}'.format(np.__version__))
np.set_printoptions(suppress=True)

import pandas as pd
print ('Pandas version:  {}'.format(pd.__version__))
pd.set_option('display.max_rows', 500)
# Out:
# Python version: 3.9.7 (default, Oct 22 2021, 13:24:00)
# [Clang 13.0.0 (clang-1300.0.29.3)]
# NumPy version: 1.21.3
# Pandas version:  1.2.4

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Vehicle.csv from CRSS

# %%
def Import_Data_Vehicle():
    print ('Import_Data_Vehicle()')

    df = pd.DataFrame([])
    for year in ['2016','2017','2018']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/VEHICLE.CSV'
#        filename = '../../CRSS/CRSS' + year + 'CSV/VEHICLE.CSV'
        temp = pd.read_csv(filename, index_col=None, low_memory=False)
        print (year, len(temp))
        df = df.append(temp)

    for year in ['2019','2020']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/vehicle.csv'
#        filename = '../../CRSS/CRSS' + year + 'CSV/vehicle.csv'
        temp = pd.read_csv(filename, index_col=None, encoding='latin1', low_memory=False)
        print (year, len(temp))
        df = df.append(temp)

    print (df.shape)
    print ()
    return df

# %% [markdown]
# ### person.csv from CRSS

# %%
def Import_Data_Person():
    print ('Import_Data_Person()')

    df = pd.DataFrame([])
    for year in ['2016','2017','2018']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/PERSON.CSV'
#        filename = '../../CRSS/CRSS' + year + 'CSV/PERSON.CSV'
        temp = pd.read_csv(filename, index_col=None)
        print (year, len(temp))
        df = df.append(temp)

    for year in ['2019','2020']:
        filename = '../../Big_Files/CRSS_2020_Update/CRSS' + year + 'CSV/person.csv'
#        filename = '../../CRSS/CRSS' + year + 'CSV/person.csv'
        temp = pd.read_csv(filename, index_col=None, encoding='latin1')
        print (year, len(temp))
        df = df.append(temp)

#    for feature in df:
#        print (feature)
    

#    for feature in df:
#        if 'NAME' in feature:
#            df.drop(columns=[feature], inplace=True)

    print (df.shape)
    print ()
    return df

# %% [markdown]
# ### All Data

# %%
def Import_Data():
    print ('Import_Data()')
    df_Vehicle = Import_Data_Vehicle()
    df_Person = Import_Data_Person()
    
    print ()
    return df_Vehicle, df_Person

# %% [markdown]
# # Build Database

# %%
def Build_Vehicle_Dataset(df_Vehicle):
    print ('Build_Vehicle_Dataset()')
    data = pd.DataFrame()

    F = [
        'ACC_TYPE',
        'BDYTYP_IM',
        'BODY_TYP',
        'BUS_USE',
        'CARGO_BT',
        'DEFORMED',
        'DR_PRES',
        'EMER_USE',
        'FIRE_EXP',
        'HAZ_CNO',
        'HAZ_INV',
        'HAZ_PLAC',
        'HAZ_REL',
        'HIT_RUN',
#        'HITRUN_IM',
        'IMPACT1',
        'IMPACT1_IM',
        'J_KNIFE',
        'M_HARM',
        'MAK_MOD',
        'MAKE',
        'MAX_VSEV',
        'MDLYR_IM',
        'MOD_YEAR',
        'MODEL',
        'MXVSEV_IM',
        'NUM_INJV',
        'NUMINJ_IM',
        'NUMOCCS',
        'P_CRASH1',
        'P_CRASH2',
        'P_CRASH3',
        'PCRASH1_IM',
        'PCRASH4',
        'PCRASH5',
        'ROLINLOC',
        'ROLLOVER',
        'SPEC_USE',
        'SPEEDREL',
        'TOW_VEH',
        'TOWED',
        'TRAV_SP',
        'V_ALCH_IM',
        'VALIGN',
        'VEH_ALCH',
        'VEVENT_IM',
        'VNUM_LAN',
        'VPROFILE',
        'VSPD_LIM',
        'VSURCOND',
        'VTCONT_F',
        'VTRAFCON',
        'VTRAFWAY',
        'CASENUM',
        'VEH_NO',
    ]

    for f in F:
        data[f] = df_Vehicle[f]
    
    
    print ()
    return data

# %% [markdown]
# ## Build_Person_Dataset

# %%
def Build_Person_Dataset(df_Person):
    print ('Build_Person_Dataset')
    data = pd.DataFrame()
    
    F = [
        'CASENUM',
        'VEH_NO',
#        'AGE_IM',
#        'SEX_IM',
#        'MAKE',
#        'BODY_TYP',
#        'PER_TYP',
#        'MOD_YEAR',
#        'MAK_MOD',
    ]

    for f in F:
        data[f] = df_Person[f]
        
    data['HOSPITAL'] = df_Person['HOSPITAL'].apply(lambda x:1 if x in [1,2,3,4,5] else 0)

    data = data[data.VEH_NO != 0]

    data = data.reindex(sorted(data.columns), axis=1)    
    
    print ()
    return data

# %% [markdown]
# ## Merge Datasets

# %%
def Build_Dataset(df_Vehicle, df_Person):
    print ('Build_Dataset()')
    print ()
    data_Vehicle = Build_Vehicle_Dataset(df_Vehicle)
    data_Person = Build_Person_Dataset(df_Person)
    
    
    
    U = data_Vehicle.CASENUM.unique()
    V = data_Person.CASENUM.unique()
    U = set(U)
    V = set(V)
    print ('Do all of the cases in data_Person appear in data_Vehicle?')
    print (V.issubset(U))
    print ()
    
    
    
#    data = pd.merge(
#        data_Vehicle, data_Person, 
#        on=['CASENUM', 'VEH_NO'],
#        how="outer", sort=False
#    )
    
    data = pd.merge(
        data_Person, data_Vehicle, 
        left_on=['CASENUM', 'VEH_NO'], right_on = ['CASENUM', 'VEH_NO'], 
        how="inner", sort=False
    )
    
    print ('data_Vehicle.shape')
    print (data_Vehicle.shape)
    print ('data_Person.shape')
    print (data_Person.shape)
    print ('data.shape')
    print (data.shape)
    

#    data.drop(columns=['CASENUM'], inplace=True)
#    data.astype(bool)

    print (data.head())

    return data

# %% [markdown]
# ## Feature Names

# %%
def Feature_Names(data, Named_Features):
    print ('Feature_Names')
    D = {}
    for f in Named_Features:
        g = f + 'NAME'
        A = pd.concat([data[f],data[g]], axis=1)
        A.drop_duplicates(inplace=True)
        A.dropna(inplace=True)
#        print (f)
#        print (len(A))
#        print (A.head())
#        print ()
        B = dict(zip(A[f],A[g]))
        D[f] = B
#        print (B)
#        print ()
#    print (D)
    print ()
    return D

# %%
def Remove_Unknowns_in_Feature(data, feature):
    
    Unknowns = {
        'HOSPITAL': [],
        'ACC_TYPE': [99],
        'BDYTYP_IM': [],
        'BODY_TYP': [98, 99, 49, 79],
        'BUS_USE': [98, 99],
        'CARGO_BT': [98, 99],
        'DEFORMED': [8, 9],
        'DR_PRES': [9],
        'EMER_USE': [8, 9],
        'FIRE_EXP': [],
        'HAZ_CNO': [88],
        'HAZ_INV': [],
        'HAZ_PLAC': [8],
        'HAZ_REL': [8],
        'HIT_RUN': [9],
        'IMPACT1': [98, 99],
        'IMPACT1_IM': [],
        'J_KNIFE': [],
        'M_HARM': [98, 99],
        'MAK_MOD': [],
        'MAKE': [99],
        'MAX_VSEV': [9],
        'MDLYR_IM': [],
        'MOD_YEAR': [9998, 9999],
        'MODEL': [],
        'MXVSEV_IM': [],
        'NUM_INJV': [99],
        'NUMINJ_IM': [],
        'NUMOCCS': [99],
        'P_CRASH1': [99],
        'P_CRASH2': [99],
        'P_CRASH3': [99],
        'PCRASH1_IM': [],
        'PCRASH4': [9],
        'PCRASH5': [9],
        'ROLINLOC': [9],
        'ROLLOVER': [],
        'SPEC_USE': [98, 99],
        'SPEEDREL': [9],
        'TOW_VEH': [9],
        'TOWED': [8, 9],
        'TRAV_SP': [998, 999],
        'V_ALCH_IM': [],
        'VALIGN': [8, 9],
        'VEH_ALCH': [9],
        'VEVENT_IM': [],
        'VNUM_LAN': [8, 9],
        'VPROFILE': [8, 9],
        'VSPD_LIM': [98, 99],
        'VSURCOND': [98, 99],
        'VTCONT_F': [8, 9],
        'VTRAFCON': [97, 99],
        'VTRAFWAY': [8, 9],
        'CASENUM': [],
        'VEH_NO': [],
    }
    
#    print ('Remove_Unknowns_in_Feature ', feature, Unknowns[feature], len(data))
    data_temp = data[~data[feature].isin(Unknowns[feature])]
#    print ('Remove_Unknowns_in_Feature ', feature, Unknowns[feature], len(data_temp))
#    print ()
    
    return data_temp, Unknowns[feature]

# %% [markdown]
# ## Correlation

# %%
def Correlation(data, target, feature, value, name):
    TN = 0
    FP = 0
    FN = 0
    TP = 0
    contingency_matrix = pd.crosstab(data[target], data[feature])
    cm = contingency_matrix.values.tolist()
    if len(cm)==2 and len(cm[0])==2:
        corr = cm[1][1] / (cm[0][1] + cm[1][1])
        per = (cm[0][1] + cm[1][1])/(cm[0][0] + cm[0][1] + cm[1][0] + cm[1][1])
    else:
        corr = 0
        per = 0
    per = round(per*100,4)
    corr = round(corr*100,4)
#    print ("    - ", feature)
#    print ("    - ", value)
#    print ("    - ", name)
#    print (contingency_matrix)
#    print ('        - per = ', per)
#    print ("        - corr = ", corr)
#    print ()
    return (per, corr)

def Correlation_by_Value(data, target, feature, Feature_Names_Dict, Unknowns):
# I decided against the np.unique because it treats each nan as a separate entry.
#    V = np.unique(data[feature].values) 
    V = data[feature].unique()
#    print (V)
    B = []

    for value in V:
        A = pd.DataFrame()
        A[feature] = data[feature].apply(lambda x: 1 if x==value else 0)
        A[target] = data[target]
        if feature in Feature_Names_Dict:
            if value in Feature_Names_Dict[feature]:
                name = Feature_Names_Dict[feature][value]
            else:
                name=str(value)
        else:
            name = str(value)
#        if len(name)>30:
#            name = name[:30]
        per, corr = Correlation(A, target, feature, value, name)
        B.append([feature, value, name, per, corr])
#    print (feature)
    B = sorted(B, key=lambda x:x[4], reverse=True)
    for b in B:
        c = b[1]
        try:
            c = int(c)
        except:
            c=c
        else:
            c = int(c)
#        print (c, end=',')
#    print ()
#    print ()

    # Print grouped into 100/p blocks of same size
    print ("    feature = '%s'" % feature)
    print ('    A = [')
    p = 20
    s = 0.0
    s2 = 0.0
    n=0
    print ("        ['%d', [" % n , end='')
    for b in B:
        t = s + b[3]
        if b[3]<10:
            s2 = s2 + b[3]
        q = int(s/p)
        r = int((t-0.001)/p)
        if r>q or b[3]>10:
            print ("]], # ", round(s2,4), '%')
            s2 = 0.0
            n += 1
            print ("        ['%d', [" % n , end='')
        s = t
        
        c = b[1]
        try:
            c = int(c)
        except:
            c=c
        else:
            c = int(c)
        print (c, end=',')
        if b[3]>10:
            print ("]], # ", round(b[3],4), '%')
            s2=0.0
            n += 1
            print ("        ['%d', [" % n , end='')
    print ("]], # ", round(s2,4), '%')
    print ("        ['Unknowns', [", end='')
    for u in Unknowns:
        print (u, end=', ')
    print ("]]" )
    print ('    ]')
    print ('    data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)')
    print ()
    
    C = pd.DataFrame(B)
    C.columns = ['Feature', 'Code', 'Name', 'Per', 'Corr']
#    C.drop(C[C['Per'] < 0.1].index, inplace=True)
#    print (C)
    display(C)

    TeX = open('../Correlation/Correlation_' + feature + '.tex', 'w')
    E = [c for c in B if c[3]>=0.0]
    
        
    
    for c in E:
        a = c[0]
        b = c[1]
        d = c[2]
        e = "{:.4f}".format(c[3])
        f = "{:.4f}".format(c[4])
        TeX.write('\t & \\verb|%s| & %s & %s & %s & %s \\cr\n' % (a,b,d,e,f))
    

    TeX = open('../Correlation/Correlation_Ordered_' + feature + '.tex', 'w')
    E = sorted(B, key=lambda x:x[1], reverse=False)

    
    for c in E:
        a = c[0]
        b = c[1]
        d = c[2]
        e = "{:.4f}".format(c[3])
        f = "{:.4f}".format(c[4])
        TeX.write('\t & \\verb|%s| & %s & %s & %s & %s \\cr\n' % (a,b,d,e,f))
    

    print ()
    return B

def Correlation_All(data, target, Feature_Names_Dict):
    print ('Correlation_All')
    
    C = []
    for feature in data:
        data_temp, Unknowns = Remove_Unknowns_in_Feature(data, feature)
        U = data_temp[feature].unique()
#        print (feature, len(U))
        if len(U)<10000:
            B = Correlation_by_Value(
                data_temp, target, feature, Feature_Names_Dict, Unknowns
            )
            for b in B:
                C.append(b)
#            print ()
#        print ()
#    for c in C:
#        print (c)
#    print ()
    C = sorted(C, key=lambda x:x[4], reverse=True)
    D = pd.DataFrame(C)
    D.columns = ['Feature', 'Code', 'Name', 'Per', 'Corr']
    print (D)
    print ()
    
    D.drop(D[D['Per'] < 0.5].index, inplace=True)
    print (D)
    print ()
    
    TeX = open('../Correlation/Correlation.tex', 'w')
    E = [c for c in C if c[3]>=0.5]
    
    for c in E:
        a = c[0]
        b = c[1]
        d = c[2]
        e = "{:.4f}".format(c[3])
        f = "{:.4f}".format(c[4])
        TeX.write('\\verb|%s| & %s & %s & %s & %s \\cr\n' % (a,b,d,e,f))
    
    return 0

# %% [markdown]
# # Main()

# %%
def Main():
    target = 'HOSPITAL'
    df_Vehicle, df_Person = Import_Data()
    
    """
    print ('Features in df_Vehicle, with Number of Unique Values and Number of Blank Values')
    for feature in df_Vehicle:
        U = df_Vehicle[feature].unique()
        s = df_Vehicle[feature].isna().sum()
        print (feature, len(U), s)
    print ()

    print ('Features in df_Person, with Number of Unique Values and Number of Blank Values')
    for feature in df_Person:
        U = df_Person[feature].unique()
        s = df_Person[feature].isna().sum()
        print (feature, len(U), s)

    print ()
    """
    
    data = Build_Dataset(df_Vehicle, df_Person)
    
    print ('Features in data, with Number of Unique Values and Number of Blank Values')
    for feature in data:
        U = data[feature].unique()
        s = data[feature].isna().sum()
        print (feature, len(U), s)
    print ()
    
    """
    print ('Features in df_Vehicle with Names')
    F = []
    for feature in df_Vehicle:
        if 'NAME' in feature:
            f = feature[:-4]
            if f in data:
                F.append(f)
    F = sorted(F)
    for f in F:
        print ("        '%s'," % f)
    print ()
    """
       
    Named_Features_df_Vehicle = [
        'ACC_TYPE',
        'BDYTYP_IM',
        'BUS_USE',
        'CARGO_BT',
        'DEFORMED',
        'DR_PRES',
        'EMER_USE',
        'FIRE_EXP',
        'HAZ_CNO',
        'HAZ_INV',
        'HAZ_PLAC',
        'HAZ_REL',
#        'HITRUN_IM',
        'HIT_RUN',
        'IMPACT1',
        'IMPACT1_IM',
        'J_KNIFE',
        'MAK_MOD',
        'MAX_VSEV',
        'MDLYR_IM',
        'MOD_YEAR',
        'MXVSEV_IM',
        'M_HARM',
        'NUMINJ_IM',
        'NUMOCCS',
        'NUM_INJV',
        'PCRASH1_IM',
        'PCRASH4',
        'PCRASH5',
        'P_CRASH1',
        'P_CRASH2',
        'P_CRASH3',
        'ROLINLOC',
        'ROLLOVER',
        'SPEC_USE',
        'SPEEDREL',
        'TOWED',
        'TOW_VEH',
        'TRAV_SP',
        'VALIGN',
        'VEH_ALCH',
        'VEVENT_IM',
        'VNUM_LAN',
        'VPROFILE',
        'VSPD_LIM',
        'VSURCOND',
        'VTCONT_F',
        'VTRAFCON',
        'VTRAFWAY',
        'V_ALCH_IM',
    ]

    Feature_Names_Dict = Feature_Names(df_Vehicle, Named_Features_df_Vehicle)

    Named_Features_df_Person = [
        'HOSPITAL',
#        'MAK_MOD',
#        'SEX_IM',
#        'MAKE',
#        'BODY_TYP',
#        'PER_TYP'
#        'MOD_YEAR',
    ]

    Feature_Names_Dict.update(Feature_Names(df_Person, Named_Features_df_Person))

#    print (Feature_Names_Dict)

    Correlation_All(data, target, Feature_Names_Dict)


Main()
# Out:
# Import_Data()
# Import_Data_Vehicle()
# 2016 82149
# 2017 97625
# 2018 86105
# 2019 96717
# 2020 94718
# (457314, 184)
#
# Import_Data_Person()
# 2016 117759
# 2017 138913
# 2018 120230
# 2019 135410
# 2020 131962
# (644274, 117)
#
#
# Build_Dataset()
#
# Build_Vehicle_Dataset()
#
# Build_Person_Dataset
#
# Do all of the cases in data_Person appear in data_Vehicle?
# True
#
# data_Vehicle.shape
# (457314, 54)
# data_Person.shape
# (621222, 3)
# data.shape
# (619027, 55)
#         CASENUM  HOSPITAL  VEH_NO  ACC_TYPE  BDYTYP_IM  BODY_TYP  BUS_USE  \
# 0  201600014311         0       1        46          4         4        0
# 1  201600014311         0       2        45          5         5        0
# 2  201600014315         0       1        68         31        31        0
# 3  201600014315         0       2        69         30        30        0
# 4  201600014315         0       2        69         30        30        0
#
#    CARGO_BT  DEFORMED  DR_PRES  ...  VALIGN  VEH_ALCH  VEVENT_IM  VNUM_LAN  \
# 0         0         4        1  ...       1         2         12         8
# 1         0         4        1  ...       1         2         12         8
# 2         0         6        1  ...       1         2         12         8
# 3         0         6        1  ...       1         2         12         8
# 4         0         6        1  ...       1         2         12         8
#
#    VPROFILE  VSPD_LIM  VSURCOND  VTCONT_F  VTRAFCON  VTRAFWAY
# 0         1        30         1         8        97         8
# 1         1        30         1         8        97         8
# 2         2        30         1         8        97         8
# 3         2        30         1         8        97         8
# 4         2        30         1         8        97         8
#
# [5 rows x 55 columns]
# Features in data, with Number of Unique Values and Number of Blank Values
# CASENUM 258896 0
# HOSPITAL 2 0
# VEH_NO 15 0
# ACC_TYPE 91 0
# BDYTYP_IM 69 0
# BODY_TYP 73 0
# BUS_USE 9 0
# CARGO_BT 18 0
# DEFORMED 6 0
# DR_PRES 3 0
# EMER_USE 8 0
# FIRE_EXP 2 0
# HAZ_CNO 10 0
# HAZ_INV 2 0
# HAZ_PLAC 4 0
# HAZ_REL 4 0
# HIT_RUN 3 0
# IMPACT1 26 0
# IMPACT1_IM 24 0
# J_KNIFE 4 0
# M_HARM 56 0
# MAK_MOD 1200 0
# MAKE 70 0
# MAX_VSEV 8 0
# MDLYR_IM 81 0
# MOD_YEAR 83 0
# MODEL 140 0
# MXVSEV_IM 7 0
# NUM_INJV 16 0
# NUMINJ_IM 15 0
# NUMOCCS 65 0
# P_CRASH1 20 0
# P_CRASH2 57 0
# P_CRASH3 14 0
# PCRASH1_IM 19 0
# PCRASH4 8 0
# PCRASH5 9 0
# ROLINLOC 9 0
# ROLLOVER 4 0
# SPEC_USE 20 0
# SPEEDREL 7 0
# TOW_VEH 8 0
# TOWED 6 0
# TRAV_SP 123 0
# V_ALCH_IM 2 0
# VALIGN 7 0
# VEH_ALCH 4 0
# VEVENT_IM 55 0
# VNUM_LAN 10 0
# VPROFILE 9 0
# VSPD_LIM 20 0
# VSURCOND 13 0
# VTCONT_F 7 0
# VTRAFCON 19 0
# VTRAFWAY 9 0
#
# Feature_Names
#
# Feature_Names
#
# Correlation_All
#     feature = 'HOSPITAL'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [0,]], #  14.4076 %
#         ['2', []], #  0.0 %
#         ['3', [1,]], #  14.4076 %
#         ['4', []], #  0.0 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                           Name      Per   Corr
# 0  HOSPITAL     0  Not Transported for Treatment  14.4076  100.0
# 1  HOSPITAL     1                        EMS Air  14.4076  100.0
#     feature = 'VEH_NO'
#     A = [
#         ['0', [13,7,8,]], #  0.0275 %
#         ['1', [1,]], #  54.403 %
#         ['2', [9,]], #  0.0044 %
#         ['3', [2,]], #  40.0519 %
#         ['4', [6,10,3,5,4,11,12,14,15,]], #  5.5133 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code Name      Per     Corr
# 0   VEH_NO    13   13   0.0010  66.6667
# 1   VEH_NO     7    7   0.0173  17.7570
# 2   VEH_NO     8    8   0.0092  15.7895
# 3   VEH_NO     1    1  54.4030  15.0418
# 4   VEH_NO     9    9   0.0044  14.8148
# 5   VEH_NO     2    2  40.0519  14.1232
# 6   VEH_NO     6    6   0.0483  13.3779
# 7   VEH_NO    10   10   0.0015  11.1111
# 8   VEH_NO     3    3   4.4416  10.3582
# 9   VEH_NO     5    5   0.1788   9.8464
# 10  VEH_NO     4    4   0.8404   9.2464
# 11  VEH_NO    11   11   0.0010   0.0000
# 12  VEH_NO    12   12   0.0006   0.0000
# 13  VEH_NO    14   14   0.0003   0.0000
# 14  VEH_NO    15   15   0.0008   0.0000
#     feature = 'ACC_TYPE'
#     A = [
#         ['0', [61,60,51,50,53,59,52,55,58,6,54,1,10,14,16,5,2,7,8,4,0,62,3,9,89,69,41,64,66,87,90,91,]], #  21.7211 %
#         ['1', [83,34,35,88,68,65,86,30,82,38,73,39,]], #  20.5914 %
#         ['2', [98,25,22,11,31,77,12,40,85,24,26,32,71,81,79,29,27,43,]], #  22.3576 %
#         ['3', [21,33,42,48,75,72,80,15,78,28,76,44,45,84,49,]], #  22.3708 %
#         ['4', [20,67,23,74,47,70,46,93,13,92,63,36,37,]], #  12.9592 %
#         ['Unknowns', [99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code                                               Name     Per  \
# 0   ACC_TYPE    61  H61-Same Trafficway, Opposite Direction-Forwar...  0.0023
# 1   ACC_TYPE    60  H60-Same Trafficway, Opposite Direction-Forwar...  0.0021
# 2   ACC_TYPE    51  G51-Same Trafficway, Opposite Direction-Head-O...  0.6003
# 3   ACC_TYPE    50  G50-Same Trafficway, Opposite Direction-Head-O...  0.4971
# 4   ACC_TYPE    53  G53-Same Trafficway, Opposite Direction-Head-O...  0.0275
# 5   ACC_TYPE    59  H59-Same Trafficway, Opposite Direction-Forwar...  0.0137
# 6   ACC_TYPE    52  G52-Same Trafficway, Opposite Direction-Head-O...  0.1791
# 7   ACC_TYPE    55  H55-Same Trafficway, Opposite Direction-Forwar...  0.0011
# 8   ACC_TYPE    58  H58-Same Trafficway, Opposite Direction-Forwar...  0.0122
# 9   ACC_TYPE     6  B6-Single Driver-Left Roadside Departure-Drive...  1.9688
# 10  ACC_TYPE    54  H54-Same Trafficway, Opposite Direction-Forwar...  0.0013
# 11  ACC_TYPE     1  A1-Single Driver-Right Roadside Departure-Driv...  2.8903
# 12  ACC_TYPE    10  B10-Single Driver-Left Roadside Departure-Spec...  0.0510
# 13  ACC_TYPE    14     C14-Single Driver-Forward Impact-End Departure  0.1999
# 14  ACC_TYPE    16  C16-Single Driver-Forward Impact-Specifics Unk...  0.0348
# 15  ACC_TYPE     5  A5-Single Driver-Right Roadside Departure-Spec...  0.0717
# 16  ACC_TYPE     2  A2-Single Driver-Right Roadside Departure-Cont...  1.3208
# 17  ACC_TYPE     7  B7-Single Driver-Left Roadside Departure-Contr...  1.1679
# 18  ACC_TYPE     8  B8-Single Driver-Left Roadside Departure-Avoid...  0.2452
# 19  ACC_TYPE     4  A4-Single Driver-Right Roadside Departure-Spec...  0.0177
# 20  ACC_TYPE     0                                       M0-No Impact  0.3171
# 21  ACC_TYPE    62  H62-Same Trafficway, Opposite Direction-Forwar...  0.0072
# 22  ACC_TYPE     3  A3-Single Driver-Right Roadside Departure-Avoi...  0.4055
# 23  ACC_TYPE     9  B9-Single Driver-Left Roadside Departure-Speci...  0.0133
# 24  ACC_TYPE    89  L89-Intersecting Paths-Straight Paths-Struck o...  2.0118
# 25  ACC_TYPE    69  J69-Trafficway Vehicle Turning-Turn Across Pat...  4.0271
# 26  ACC_TYPE    41  E41-Same Trafficway, Same Direction-Forward Im...  0.0013
# 27  ACC_TYPE    64  I64-Same Trafficway, Opposite Direction-Angle,...  0.5737
# 28  ACC_TYPE    66  I66-Same Trafficway, Opposite Direction-Angle,...  0.2015
# 29  ACC_TYPE    87  L87-Intersecting Paths-Straight Paths-Struck o...  2.1015
# 30  ACC_TYPE    90  L90-Intersecting Paths-Straight Paths-Specific...  0.2584
# 31  ACC_TYPE    91  L91-Intersecting Paths-Straight Paths-Specific...  0.1084
# 32  ACC_TYPE    83  K83-Trafficway Vehicle Turning-Turn Into Path-...  2.3895
# 33  ACC_TYPE    34  E34-Same Trafficway, Same Direction-Forward Im...  0.0008
# 34  ACC_TYPE    35  E35-Same Trafficway, Same Direction-Forward Im...  0.0008
# 35  ACC_TYPE    88  L88-Intersecting Paths-Straight Paths-Striking...  1.8964
# 36  ACC_TYPE    68  J68-Trafficway Vehicle Turning-Turn Across Pat...  3.9523
# 37  ACC_TYPE    65  I65-Same Trafficway, Opposite Direction-Angle,...  0.6728
# 38  ACC_TYPE    86  L86-Intersecting Paths-Straight Paths-Striking...  2.0065
# 39  ACC_TYPE    30  D30-Same Trafficway, Same Direction-Rear End-D...  0.1719
# 40  ACC_TYPE    82  K82-Trafficway Vehicle Turning-Turn Into Path-...  2.3843
# 41  ACC_TYPE    38  E38-Same Trafficway, Same Direction-Forward Im...  0.0107
# 42  ACC_TYPE    73  J73-Trafficway Vehicle Turning-Turn Across Pat...  0.4195
# 43  ACC_TYPE    39  E39-Same Trafficway, Same Direction-Forward Im...  0.0141
# 44  ACC_TYPE    98                               M98-Other Crash Type  9.0613
# 45  ACC_TYPE    25  D25-Same Trafficway, Same Direction-Rear End-S...  2.1789
# 46  ACC_TYPE    22  D22-Same Trafficway, Same Direction-Rear End-S...  0.7676
# 47  ACC_TYPE    11       C11-Single Driver-Forward Impact-Parked Veh.  1.2195
# 48  ACC_TYPE    31  D31-Same Trafficway, Same Direction-Rear End-D...  0.2539
# 49  ACC_TYPE    77  K77-Trafficway Vehicle Turning-Turn Into Path-...  0.8688
# 50  ACC_TYPE    12       C12-Single Driver-Forward Impact-Sta. Object  0.2426
# 51  ACC_TYPE    40  E40-Same Trafficway, Same Direction-Forward Im...  0.0013
# 52  ACC_TYPE    85  K85-Trafficway Vehicle Turning-Turn Into Path-...  0.2038
# 53  ACC_TYPE    24  D24-Same Trafficway, Same Direction-Rear End-S...  2.0937
# 54  ACC_TYPE    26  D26-Same Trafficway, Same Direction-Rear End-S...  0.1087
# 55  ACC_TYPE    32  D32-Same Trafficway, Same Direction-Rear End-S...  0.8243
# 56  ACC_TYPE    71  J71-Trafficway Vehicle Turning-Turn Across Pat...  0.3213
# 57  ACC_TYPE    81  K81-Trafficway Vehicle Turning-Turn Into Path-...  0.2513
# 58  ACC_TYPE    79  K79-Trafficway Vehicle Turning-Turn Into Path-...  0.9481
# 59  ACC_TYPE    29  D29-Same Trafficway, Same Direction-Rear End-D...  2.9457
# 60  ACC_TYPE    27  D27-Same Trafficway, Same Direction-Rear End-S...  0.1739
# 61  ACC_TYPE    43  E43-Same Trafficway, Same Direction-Forward Im...  0.0033
# 62  ACC_TYPE    21  D21-Same Trafficway, Same Direction-Rear End-S...  8.9509
# 63  ACC_TYPE    33  D33-Same Trafficway, Same Direction-Rear End-S...  0.7448
# 64  ACC_TYPE    42  E42-Same Trafficway, Same Direction-Forward Im...  0.0036
# 65  ACC_TYPE    48  F48-Same Trafficway, Same Direction-Angle, Sid...  1.3369
# 66  ACC_TYPE    75  J75-Trafficway Vehicle Turning-Turn Across Pat...  0.0657
# 67  ACC_TYPE    72  J72-Trafficway Vehicle Turning-Turn Across Pat...  0.4447
# 68  ACC_TYPE    80  K80-Trafficway Vehicle Turning-Turn Into Path-...  0.2178
# 69  ACC_TYPE    15   C15-Single Driver-Forward Impact-Specifics Other  0.1578
# 70  ACC_TYPE    78  K78-Trafficway Vehicle Turning-Turn Into Path-...  0.9082
# 71  ACC_TYPE    28  D28-Same Trafficway, Same Direction-Rear End-D...  3.0105
# 72  ACC_TYPE    76  K76-Trafficway Vehicle Turning-Turn Into Path-...  0.8266
# 73  ACC_TYPE    44  F44-Same Trafficway, Same Direction-Angle, Sid...  0.8570
# 74  ACC_TYPE    45  F45-Same Trafficway, Same Direction-Angle, Sid...  3.6517
# 75  ACC_TYPE    84  K84-Trafficway Vehicle Turning-Turn Into Path-...  0.7263
# 76  ACC_TYPE    49  F49-Same Trafficway, Same Direction-Angle, Sid...  0.5183
# 77  ACC_TYPE    20  D20-Same Trafficway, Same Direction-Rear End-S...  8.9009
# 78  ACC_TYPE    67  I67-Same Trafficway, Opposite Direction-Angle,...  0.0770
# 79  ACC_TYPE    23  D23-Same Trafficway, Same Direction-Rear End-S...  0.7297
# 80  ACC_TYPE    74  J74-Trafficway Vehicle Turning-Turn Across Pat...  0.9932
# 81  ACC_TYPE    47  F47-Same Trafficway, Same Direction-Angle, Sid...  1.4206
# 82  ACC_TYPE    70  J70-Trafficway Vehicle Turning-Turn Across Pat...  0.3291
# 83  ACC_TYPE    46  F46-Same Trafficway, Same Direction-Angle, Sid...  1.3494
# 84  ACC_TYPE    93                          M93-Backing-Other Vehicle  0.7817
# 85  ACC_TYPE    13  C13-Single Driver-Forward Impact-Pedestrian/ A...  5.9658
# 86  ACC_TYPE    92                           M92-Backing-Backing Veh.  1.3107
# 87  ACC_TYPE    63  H63-Same Trafficway, Opposite Direction-Forwar...  0.0010
# 88  ACC_TYPE    36  E36-Same Trafficway, Same Direction-Forward Im...  0.0003
# 89  ACC_TYPE    37  E37-Same Trafficway, Same Direction-Forward Im...  0.0007
#
#        Corr
# 0   92.8571
# 1   69.2308
# 2   53.5734
# 3   50.9317
# 4   45.5621
# 5   45.2381
# 6   44.4646
# 7   42.8571
# 8   41.3333
# 9   38.7238
# 10  37.5000
# 11  37.1457
# 12  36.6242
# 13  35.4472
# 14  35.0467
# 15  34.6939
# 16  34.4654
# 17  33.4122
# 18  30.6163
# 19  30.2752
# 20  27.4731
# 21  27.2727
# 22  26.9339
# 23  26.8293
# 24  26.3026
# 25  25.1705
# 26  25.0000
# 27  24.5042
# 28  23.2258
# 29  22.0942
# 30  21.5723
# 31  20.9895
# 32  20.9481
# 33  20.0000
# 34  20.0000
# 35  19.5732
# 36  18.4547
# 37  18.3575
# 38  18.2569
# 39  17.6749
# 40  16.7950
# 41  15.1515
# 42  15.0329
# 43  14.9425
# 44  14.2301
# 45  14.1866
# 46  13.6142
# 47  13.3129
# 48  13.1882
# 49  13.0939
# 50  12.6591
# 51  12.5000
# 52  12.3604
# 53  12.2720
# 54  12.1076
# 55  11.8297
# 56  11.6844
# 57  11.5136
# 58  11.4673
# 59  10.4938
# 60  10.1869
# 61  10.0000
# 62   9.8192
# 63   9.3170
# 64   9.0909
# 65   8.8743
# 66   8.6634
# 67   8.5161
# 68   8.1343
# 69   7.8270
# 70   7.7845
# 71   7.7737
# 72   7.7468
# 73   7.1307
# 74   6.7604
# 75   6.4220
# 76   6.3343
# 77   5.7205
# 78   5.6962
# 79   5.5234
# 80   5.3510
# 81   4.9765
# 82   4.7407
# 83   4.3840
# 84   3.6798
# 85   2.1657
# 86   1.5995
# 87   0.0000
# 88   0.0000
# 89   0.0000
#     feature = 'BDYTYP_IM'
#     A = [
#         ['0', [86,87,82,89,81,83,84,80,88,85,90,95,11,97,96,58,12,45,32,91,10,2,59,3,30,]], #  7.1472 %
#         ['1', [4,]], #  36.3414 %
#         ['2', [1,19,42,5,8,16,6,52,]], #  10.832 %
#         ['3', [14,]], #  15.7266 %
#         ['4', [9,20,22,40,]], #  16.7815 %
#         ['5', [34,31,15,29,39,55,92,17,21,50,93,48,7,28,51,61,67,63,62,66,65,78,64,72,60,71,73,94,41,13,]], #  13.1715 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#       Feature  Code                                               Name  \
# 0   BDYTYP_IM    86                                                 86
# 1   BDYTYP_IM    87                Unknown Three Wheel Motorcycle Type
# 2   BDYTYP_IM    82             Three-wheel Motorcycle (2 Rear Wheels)
# 3   BDYTYP_IM    89                         Unknown motored cycle type
# 4   BDYTYP_IM    81                         Moped or motorized bicycle
# 5   BDYTYP_IM    83                                Off-road Motorcycle
# 6   BDYTYP_IM    84                                      Motor Scooter
# 7   BDYTYP_IM    80    Two Wheel Motorcycle (excluding motor scooters)
# 8   BDYTYP_IM    88  Other motored cycle type (mini-bikes, pocket m...
# 9   BDYTYP_IM    85  Unenclosed Three Wheel Motorcycle / Unenclosed...
# 10  BDYTYP_IM    90                        ATV/ATC [All-Terrain Cycle]
# 11  BDYTYP_IM    95                                          Golf Cart
# 12  BDYTYP_IM    11  Auto-based panel (cargo station wagon, auto-ba...
# 13  BDYTYP_IM    97  Other vehicle type (includes go-cart, fork-lif...
# 14  BDYTYP_IM    96                   Recreational Off-Highway Vehicle
# 15  BDYTYP_IM    58                                     Other Bus Type
# 16  BDYTYP_IM    12  Large Limousine-more than four side doors or s...
# 17  BDYTYP_IM    45                Other light conventional truck type
# 18  BDYTYP_IM    32                                                 32
# 19  BDYTYP_IM    91                                         Snowmobile
# 20  BDYTYP_IM    10  Auto-based pickup (includes E1 Camino, Caballe...
# 21  BDYTYP_IM     2                         2-door sedan,hardtop,coupe
# 22  BDYTYP_IM    59                                   Unknown Bus Type
# 23  BDYTYP_IM     3                            3-door/2-door hatchback
# 24  BDYTYP_IM    30                                                 30
# 25  BDYTYP_IM     4                              4-door sedan, hardtop
# 26  BDYTYP_IM     1               Convertible(excludes sun-roof,t-bar)
# 27  BDYTYP_IM    19                 Utility Vehicle, Unknown body type
# 28  BDYTYP_IM    42   Light Vehicle Based Motor Home (chassis mounted)
# 29  BDYTYP_IM     5                            5-door/4-door hatchback
# 30  BDYTYP_IM     8             Sedan/Hardtop, number of doors unknown
# 31  BDYTYP_IM    16  Utility station wagon (includes suburban limou...
# 32  BDYTYP_IM     6      Station Wagon (excluding van and truck based)
# 33  BDYTYP_IM    52                             Transit Bus (City Bus)
# 34  BDYTYP_IM    14  Compact Utility (Utility Vehicle Categories "S...
# 35  BDYTYP_IM     9                   Other or Unknown automobile type
# 36  BDYTYP_IM    20  Minivan (Chrysler Town and Country, Caravan, G...
# 37  BDYTYP_IM    22  Step-van or walk-in van (GVWR less than or equ...
# 38  BDYTYP_IM    40  Cab Chassis Based (includes Rescue Vehicle, Li...
# 39  BDYTYP_IM    34                                       Light Pickup
# 40  BDYTYP_IM    31                                                 31
# 41  BDYTYP_IM    15  Large utility (ANSI D16.1 Utility Vehicle Cate...
# 42  BDYTYP_IM    29                                   Unknown van type
# 43  BDYTYP_IM    39  Unknown (pickup style) light conventional truc...
# 44  BDYTYP_IM    55        Van-Based Bus GVWR greater than 10,000 lbs.
# 45  BDYTYP_IM    92                   Farm equipment other than trucks
# 46  BDYTYP_IM    17                                       3-door coupe
# 47  BDYTYP_IM    21  Large Van-Includes van-based buses (B150-B350,...
# 48  BDYTYP_IM    50                                         School Bus
# 49  BDYTYP_IM    93  Construction equipment other than trucks (incl...
# 50  BDYTYP_IM    48                           Unknown light truck type
# 51  BDYTYP_IM     7                 Hatchback, number of doors unknown
# 52  BDYTYP_IM    28                 Other van type (Hi-Cube Van, Kary)
# 53  BDYTYP_IM    51                        Cross Country/Intercity Bus
# 54  BDYTYP_IM    61  Single-unit straight truck or Cab-Chassis (GVW...
# 55  BDYTYP_IM    67  Medium/heavy Pickup (GVWR greater than 10,000 ...
# 56  BDYTYP_IM    63  Single-unit straight truck or Cab-Chassis (GVW...
# 57  BDYTYP_IM    62  Single-unit straight truck or Cab-Chassis (GVW...
# 58  BDYTYP_IM    66  Truck-tractor (Cab only, or with any number of...
# 59  BDYTYP_IM    65              Medium/Heavy Vehicle Based Motor Home
# 60  BDYTYP_IM    78                    Unknown medium/heavy truck type
# 61  BDYTYP_IM    64  Single-unit straight truck or Cab-Chassis (GVW...
# 62  BDYTYP_IM    72  Unknown if single-unit or combination unit Hea...
# 63  BDYTYP_IM    60           Step van (GVWR greater than 10,000 lbs.)
# 64  BDYTYP_IM    71  Unknown if single-unit or combination unit Med...
# 65  BDYTYP_IM    73            Camper or motorhome, unknown truck type
# 66  BDYTYP_IM    94  Low Speed Vehicle (LSV) / Neighborhood Electri...
# 67  BDYTYP_IM    41                                                 41
# 68  BDYTYP_IM    13                                                 13
#
#         Per      Corr
# 0    0.0002  100.0000
# 1    0.0010   83.3333
# 2    0.0103   70.3125
# 3    0.1119   64.0693
# 4    0.0861   63.4146
# 5    0.0360   62.3318
# 6    0.1439   61.3917
# 7    2.2472   60.1898
# 8    0.0292   57.4586
# 9    0.0079   55.1020
# 10   0.0265   40.2439
# 11   0.0052   31.2500
# 12   0.0011   28.5714
# 13   0.0058   27.7778
# 14   0.0065   25.0000
# 15   0.0191   24.5763
# 16   0.0032   20.0000
# 17   0.0026   18.7500
# 18   0.0010   16.6667
# 19   0.0010   16.6667
# 20   0.0150   16.1290
# 21   3.1385   15.4468
# 22   0.0326   15.3465
# 23   0.7925   15.1855
# 24   0.4229   15.0879
# 25  36.3414   15.0367
# 26   0.6690   14.9481
# 27   1.0675   14.3311
# 28   0.0011   14.2857
# 29   2.5899   13.7849
# 30   0.7635   13.7114
# 31   0.3106   13.3125
# 32   5.2621   13.2990
# 33   0.1683   13.1478
# 34  15.7266   13.1358
# 35   3.1272   12.5736
# 36   4.1522   12.4538
# 37   0.0144   12.3596
# 38   0.0837   11.9691
# 39   9.4040   11.2655
# 40   1.6547   10.8269
# 41   5.2066   10.6981
# 42   0.2168    9.9851
# 43   0.5371    9.9248
# 44   0.0586    9.6419
# 45   0.0273    9.4675
# 46   0.0171    9.4340
# 47   1.1849    8.6435
# 48   0.1981    7.8303
# 49   0.0068    7.1429
# 50   0.1105    7.0175
# 51   0.0081    6.0000
# 52   0.0082    5.8824
# 53   0.0120    5.4054
# 54   0.6387    5.2352
# 55   0.4333    4.4743
# 56   0.4703    4.2941
# 57   0.3005    3.6559
# 58   1.6922    3.4368
# 59   0.0399    2.8340
# 60   0.1262    2.5608
# 61   0.1762    2.4748
# 62   0.0069    2.3256
# 63   0.0270    1.1976
# 64   0.0071    0.0000
# 65   0.0042    0.0000
# 66   0.0018    0.0000
# 67   0.0002    0.0000
# 68   0.0002    0.0000
#     feature = 'BODY_TYP'
#     A = [
#         ['0', [86,87,82,89,81,83,80,84,88,85,90,95,11,97,96,58,45,12,32,91,10,2,3,59,1,30,]], #  7.8638 %
#         ['1', [4,]], #  36.434 %
#         ['2', [19,42,5,8,16,6,]], #  9.943 %
#         ['3', [14,]], #  15.5655 %
#         ['4', [52,9,20,22,40,]], #  16.9082 %
#         ['5', [34,31,15,29,39,55,92,17,21,50,93,48,28,7,51,61,67,63,62,66,65,78,64,72,60,71,73,94,41,13,]], #  13.2856 %
#         ['Unknowns', [98, 99, 49, 79, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code Name      Per      Corr
# 0   BODY_TYP    86   86   0.0002  100.0000
# 1   BODY_TYP    87   87   0.0010   83.3333
# 2   BODY_TYP    82   82   0.0107   70.3125
# 3   BODY_TYP    89   89   0.1140   65.1982
# 4   BODY_TYP    81   81   0.0876   64.6272
# 5   BODY_TYP    83   83   0.0368   63.1818
# 6   BODY_TYP    80   80   2.2794   61.4972
# 7   BODY_TYP    84   84   0.1490   61.4607
# 8   BODY_TYP    88   88   0.0296   58.7571
# 9   BODY_TYP    85   85   0.0082   55.1020
# 10  BODY_TYP    90   90   0.0275   40.2439
# 11  BODY_TYP    95   95   0.0054   31.2500
# 12  BODY_TYP    11   11   0.0012   28.5714
# 13  BODY_TYP    97   97   0.0060   27.7778
# 14  BODY_TYP    96   96   0.0067   25.0000
# 15  BODY_TYP    58   58   0.0196   24.7863
# 16  BODY_TYP    45   45   0.0022   23.0769
# 17  BODY_TYP    12   12   0.0033   20.0000
# 18  BODY_TYP    32   32   0.0010   16.6667
# 19  BODY_TYP    91   91   0.0010   16.6667
# 20  BODY_TYP    10   10   0.0147   15.9091
# 21  BODY_TYP     2    2   3.1430   15.6961
# 22  BODY_TYP     3    3   0.7870   15.4894
# 23  BODY_TYP    59   59   0.0337   15.4229
# 24  BODY_TYP     1    1   0.6643   15.3264
# 25  BODY_TYP    30   30   0.4307   15.2799
# 26  BODY_TYP     4    4  36.4340   15.2598
# 27  BODY_TYP    19   19   1.0637   14.5781
# 28  BODY_TYP    42   42   0.0012   14.2857
# 29  BODY_TYP     5    5   2.5651   14.0162
# 30  BODY_TYP     8    8   0.7609   13.9085
# 31  BODY_TYP    16   16   0.3115   13.6022
# 32  BODY_TYP     6    6   5.2406   13.4239
# 33  BODY_TYP    14   14  15.5655   13.2724
# 34  BODY_TYP    52   52   0.1742   13.1731
# 35  BODY_TYP     9    9   3.1328   12.8020
# 36  BODY_TYP    20   20   4.1888   12.5090
# 37  BODY_TYP    22   22   0.0147   12.5000
# 38  BODY_TYP    40   40   0.0841   12.3506
# 39  BODY_TYP    34   34   9.3136   11.3111
# 40  BODY_TYP    31   31   1.6841   10.8681
# 41  BODY_TYP    15   15   5.1870   10.7635
# 42  BODY_TYP    29   29   0.2165   10.2862
# 43  BODY_TYP    39   39   0.5377    9.9035
# 44  BODY_TYP    55   55   0.0598    9.8039
# 45  BODY_TYP    92   92   0.0268    9.3750
# 46  BODY_TYP    17   17   0.0171    8.8235
# 47  BODY_TYP    21   21   1.1784    8.6685
# 48  BODY_TYP    50   50   0.2053    7.8303
# 49  BODY_TYP    93   93   0.0065    7.6923
# 50  BODY_TYP    48   48   0.1095    7.3394
# 51  BODY_TYP    28   28   0.0080    6.2500
# 52  BODY_TYP     7    7   0.0082    6.1224
# 53  BODY_TYP    51   51   0.0122    5.4795
# 54  BODY_TYP    61   61   0.6571    5.2752
# 55  BODY_TYP    67   67   0.4468    4.4978
# 56  BODY_TYP    63   63   0.4818    4.3100
# 57  BODY_TYP    62   62   0.3096    3.6777
# 58  BODY_TYP    66   66   1.7327    3.4696
# 59  BODY_TYP    65   65   0.0414    2.8340
# 60  BODY_TYP    78   78   0.1294    2.5873
# 61  BODY_TYP    64   64   0.1809    2.5000
# 62  BODY_TYP    72   72   0.0072    2.3256
# 63  BODY_TYP    60   60   0.0276    1.2121
# 64  BODY_TYP    71   71   0.0074    0.0000
# 65  BODY_TYP    73   73   0.0044    0.0000
# 66  BODY_TYP    94   94   0.0018    0.0000
# 67  BODY_TYP    41   41   0.0002    0.0000
# 68  BODY_TYP    13   13   0.0002    0.0000
#     feature = 'BUS_USE'
#     A = [
#         ['0', [5,]], #  0.0207 %
#         ['1', [0,]], #  99.5385 %
#         ['2', [6,7,8,1,4,]], #  0.4407 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code                               Name      Per     Corr
# 0  BUS_USE     5                       Charter/Tour   0.0207  29.9213
# 1  BUS_USE     0                          Not a Bus  99.5385  14.5594
# 2  BUS_USE     6                  Transit/ Commuter   0.1855  13.8204
# 3  BUS_USE     7                            Shuttle   0.0188  13.0435
# 4  BUS_USE     8  Modified for Personal/Private Use   0.0078   8.3333
# 5  BUS_USE     1                             School   0.2208   8.2101
# 6  BUS_USE     4                          Intercity   0.0078   6.2500
#     feature = 'CARGO_BT'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [0,]], #  96.4126 %
#         ['2', [22,10,5,2,4,12,8,1,97,3,96,11,7,6,9,]], #  3.5873 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code                                  Name      Per     Corr
# 0   CARGO_BT     0                  Not Applicable (N/A)  96.4126  14.9844
# 1   CARGO_BT    22                                   Bus   0.5367  11.6186
# 2   CARGO_BT    10                                   Log   0.0183   9.9099
# 3   CARGO_BT     5                        Concrete Mixer   0.0235   9.0909
# 4   CARGO_BT     2                            Cargo Tank   0.1170   6.0478
# 5   CARGO_BT     4                                  Dump   0.2108   5.6987
# 6   CARGO_BT    12  Vehicle Towing Another Motor Vehicle   0.0207   5.5556
# 7   CARGO_BT     8                  Grain/ Chips/ Gravel   0.0319   4.6392
# 8   CARGO_BT     1                      Van/Enclosed Box   1.1624   4.4728
# 9   CARGO_BT    97                                 Other   0.7837   4.3040
# 10  CARGO_BT     3                               Flatbed   0.3085   4.0000
# 11  CARGO_BT    96                    No Cargo Body Type   0.2126   3.6378
# 12  CARGO_BT    11          Intermodal Container Chassis   0.0342   3.3654
# 13  CARGO_BT     7                        Garbage/Refuse   0.0821   1.6032
# 14  CARGO_BT     6                      Auto Transporter   0.0275   1.1976
# 15  CARGO_BT     9                          Pole-Trailer   0.0174   0.9434
#     feature = 'DEFORMED'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [6,]], #  39.2768 %
#         ['2', []], #  0.0 %
#         ['3', [4,]], #  25.1503 %
#         ['4', []], #  0.0 %
#         ['5', [2,]], #  31.9667 %
#         ['6', [0,]], #  3.6062 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code               Name      Per     Corr
# 0  DEFORMED     6   Disabling Damage  39.2768  31.6576
# 1  DEFORMED     4  Functional Damage  25.1503   7.2221
# 2  DEFORMED     2       Minor Damage  31.9667   3.5720
# 3  DEFORMED     0          No Damage   3.6062   2.6344
#     feature = 'DR_PRES'
#     A = [
#         ['0', [0,]], #  0.0216 %
#         ['1', [1,]], #  99.9784 %
#         ['2', []], #  0.0 %
#         ['Unknowns', [9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code                              Name      Per     Corr
# 0  DR_PRES     0  No Driver Present/Not Applicable   0.0216  24.6269
# 1  DR_PRES     1                               Yes  99.9784  14.4055
#     feature = 'EMER_USE'
#     A = [
#         ['0', [6,5,]], #  0.1932 %
#         ['1', [0,]], #  99.6845 %
#         ['2', [4,3,2,]], #  0.1222 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                                               Name      Per  \
# 0  EMER_USE     6  Emergency Operation, Emergency Warning Equipme...   0.0702
# 1  EMER_USE     5  Emergency Operation, Emergency Warning Equipme...   0.1230
# 2  EMER_USE     0                                     Not Applicable  99.6845
# 3  EMER_USE     4  Emergency Operation, Emergency Warning Equipme...   0.0202
# 4  EMER_USE     3                            Non-Emergency Transport   0.0114
# 5  EMER_USE     2                       Non-Emergency, Non-Transport   0.0906
#
#       Corr
# 0  20.4176
# 1  16.9536
# 2  14.5125
# 3  12.9032
# 4  11.4286
# 5  10.6115
#     feature = 'FIRE_EXP'
#     A = [
#         ['0', [1,]], #  0.2076 %
#         ['1', [0,]], #  99.7924 %
#         ['2', []], #  0.0 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                Name      Per     Corr
# 0  FIRE_EXP     1                 Yes   0.2076  40.5447
# 1  FIRE_EXP     0  No or Not Reported  99.7924  14.3532
#     feature = 'HAZ_CNO'
#     A = [
#         ['0', [9,]], #  0.0011 %
#         ['1', [0,]], #  99.9774 %
#         ['2', [1,2,8,3,4,6,5,]], #  0.0215 %
#         ['Unknowns', [88, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code            Name      Per     Corr
# 0  HAZ_CNO     9              09   0.0011  28.5714
# 1  HAZ_CNO     0  Not Applicable  99.9774  14.4107
# 2  HAZ_CNO     1              01   0.0015  11.1111
# 3  HAZ_CNO     2              02   0.0037   8.6957
# 4  HAZ_CNO     8              08   0.0024   6.6667
# 5  HAZ_CNO     3              03   0.0129   5.0000
# 6  HAZ_CNO     4              04   0.0006   0.0000
# 7  HAZ_CNO     6              06   0.0002   0.0000
# 8  HAZ_CNO     5              05   0.0002   0.0000
#     feature = 'HAZ_INV'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [1,]], #  99.9604 %
#         ['2', [2,]], #  0.0396 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code Name      Per     Corr
# 0  HAZ_INV     1   No  99.9604  14.4107
# 1  HAZ_INV     2  Yes   0.0396   6.5306
#     feature = 'HAZ_PLAC'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [0,]], #  99.9654 %
#         ['2', [2,1,]], #  0.0345 %
#         ['Unknowns', [8, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code            Name      Per     Corr
# 0  HAZ_PLAC     0  Not Applicable  99.9654  14.4107
# 1  HAZ_PLAC     2             Yes   0.0305   5.2910
# 2  HAZ_PLAC     1              No   0.0040   0.0000
#     feature = 'HAZ_REL'
#     A = [
#         ['0', [2,]], #  0.0066 %
#         ['1', [0,]], #  99.9682 %
#         ['2', [1,]], #  0.0252 %
#         ['Unknowns', [8, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code            Name      Per     Corr
# 0  HAZ_REL     2             Yes   0.0066  21.9512
# 1  HAZ_REL     0  Not Applicable  99.9682  14.4107
# 2  HAZ_REL     1              No   0.0252   1.9231
#     feature = 'HIT_RUN'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [0,]], #  94.8247 %
#         ['2', [1,]], #  5.1753 %
#         ['Unknowns', [9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code Name      Per     Corr
# 0  HIT_RUN     0   No  94.8247  15.0601
# 1  HIT_RUN     1  Yes   5.1753   2.4504
#     feature = 'IMPACT1'
#     A = [
#         ['0', [0,14,61,9,81,3,]], #  9.5695 %
#         ['1', [12,]], #  42.3692 %
#         ['2', [62,11,]], #  8.9371 %
#         ['3', [10,1,82,2,8,4,63,19,20,83,]], #  12.8232 %
#         ['4', [6,]], #  22.3991 %
#         ['5', [7,5,13,18,]], #  3.9018 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                                               Name      Per  \
# 0   IMPACT1     0                                      Non-Collision   1.7103
# 1   IMPACT1    14                                      Undercarriage   0.2627
# 2   IMPACT1    61                                               Left   1.0508
# 3   IMPACT1     9                                      9 Clock Point   2.7188
# 4   IMPACT1    81                                              Right   1.0533
# 5   IMPACT1     3                                      3 Clock Point   2.7736
# 6   IMPACT1    12                                     12 Clock Point  42.3692
# 7   IMPACT1    62                                    Left-Front Side   2.1626
# 8   IMPACT1    11                                     11 Clock Point   5.1710
# 9   IMPACT1    10                                     10 Clock Point   1.6035
# 10  IMPACT1     1                                      1 Clock Point   4.6738
# 11  IMPACT1    82                                   Right-Front Side   2.1638
# 12  IMPACT1     2                                      2 Clock Point   1.5178
# 13  IMPACT1     8                                      8 Clock Point   0.9851
# 14  IMPACT1     4                                      4 Clock Point   0.9821
# 15  IMPACT1    63                                     Left-Back Side   1.2372
# 16  IMPACT1    19              Other Objects or Person Set-In-Motion   0.0099
# 17  IMPACT1    20  Object Set in Motion, Unknown if Cargo/Vehicle...   0.0033
# 18  IMPACT1    83                                    Right-Back Side   1.2502
# 19  IMPACT1     6                                      6 Clock Point  22.3991
# 20  IMPACT1     7                                      7 Clock Point   1.8808
# 21  IMPACT1     5                                      5 Clock Point   1.7425
# 22  IMPACT1    13                                                Top   0.1311
# 23  IMPACT1    18                  Cargo/Vehicle Parts Set-In-Motion   0.1474
#
#        Corr
# 0   47.4035
# 1   19.9874
# 2   19.4658
# 3   18.5804
# 4   17.5235
# 5   16.5526
# 6   16.2231
# 7   14.3893
# 8   14.3313
# 9   14.0327
# 10  13.1115
# 11  12.0546
# 12  11.5075
# 13  10.4743
# 14  10.4723
# 15  10.2215
# 16  10.0000
# 17  10.0000
# 18   9.7319
# 19   9.6941
# 20   8.0664
# 21   7.8351
# 22   7.4307
# 23   0.1120
#     feature = 'IMPACT1_IM'
#     A = [
#         ['0', [0,14,61,9,81,3,]], #  9.5846 %
#         ['1', [12,]], #  42.5618 %
#         ['2', [62,11,]], #  8.9862 %
#         ['3', [10,1,82,2,4,8,63,20,83,]], #  12.9432 %
#         ['4', [6,]], #  22.0047 %
#         ['5', [19,7,13,5,18,]], #  3.9193 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#        Feature  Code                                               Name  \
# 0   IMPACT1_IM     0                                      Non-Collision
# 1   IMPACT1_IM    14                                      Undercarriage
# 2   IMPACT1_IM    61                                               Left
# 3   IMPACT1_IM     9                                      9 Clock Point
# 4   IMPACT1_IM    81                                              Right
# 5   IMPACT1_IM     3                                      3 Clock Point
# 6   IMPACT1_IM    12                                     12 Clock Point
# 7   IMPACT1_IM    62                                    Left-Front Side
# 8   IMPACT1_IM    11                                     11 Clock Point
# 9   IMPACT1_IM    10                                     10 Clock Point
# 10  IMPACT1_IM     1                                      1 Clock Point
# 11  IMPACT1_IM    82                                   Right-Front Side
# 12  IMPACT1_IM     2                                      2 Clock Point
# 13  IMPACT1_IM     4                                      4 Clock Point
# 14  IMPACT1_IM     8                                      8 Clock Point
# 15  IMPACT1_IM    63                                     Left-Back Side
# 16  IMPACT1_IM    20  Object Set in Motion, Unknown if Cargo/Vehicle...
# 17  IMPACT1_IM    83                                    Right-Back Side
# 18  IMPACT1_IM     6                                      6 Clock Point
# 19  IMPACT1_IM    19              Other Objects or Person Set-In-Motion
# 20  IMPACT1_IM     7                                      7 Clock Point
# 21  IMPACT1_IM    13                                                Top
# 22  IMPACT1_IM     5                                      5 Clock Point
# 23  IMPACT1_IM    18                  Cargo/Vehicle Parts Set-In-Motion
#
#         Per     Corr
# 0    1.6736  47.4035
# 1    0.2733  20.1537
# 2    1.0568  19.3825
# 3    2.7338  18.5192
# 4    1.0652  17.5159
# 5    2.7819  16.5612
# 6   42.5618  16.3165
# 7    2.1747  14.4184
# 8    5.2012  14.2808
# 9    1.6103  13.9647
# 10   4.7378  13.2058
# 11   2.1881  12.1742
# 12   1.5497  11.7898
# 13   0.9851  10.6592
# 14   0.9856  10.4409
# 15   1.2395  10.3089
# 16   0.0032  10.0000
# 17   1.2542   9.9176
# 18  22.0047   9.6928
# 19   0.0100   9.6774
# 20   1.8768   8.2889
# 21   0.1355   8.2241
# 22   1.7505   7.9273
# 23   0.1465   0.3308
#     feature = 'J_KNIFE'
#     A = [
#         ['0', [2,]], #  0.0483 %
#         ['1', [0,]], #  97.4523 %
#         ['2', [3,1,]], #  2.4994 %
#         ['Unknowns', []]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code                        Name      Per     Corr
# 0  J_KNIFE     2           Yes - First Event   0.0483  15.3846
# 1  J_KNIFE     0  Not an Articulated Vehicle  97.4523  14.6576
# 2  J_KNIFE     3      Yes - Subsequent Event   0.0546  14.4970
# 3  J_KNIFE     1                          No   2.4448   4.4205
#     feature = 'M_HARM'
#     A = [
#         ['0', [74,10,1,5,21,42,32,35,19,46,39,30,6,93,20,45,23,3,58,52,34,2,25,26,24,33,31,44,17,38,41,43,7,91,40,48,57,59,53,]], #  10.0639 %
#         ['1', [12,]], #  81.0472 %
#         ['2', [14,16,55,49,18,50,72,11,73,54,51,8,15,9,]], #  8.8889 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#    Feature  Code                                               Name      Per  \
# 0   M_HARM    74                              Road Vehicle on Rails   0.0008
# 1   M_HARM    10                                    Railway Vehicle   0.0105
# 2   M_HARM     1                                  Rollover/Overturn   2.6600
# 3   M_HARM     5                           Fell/Jumped from Vehicle   0.1075
# 4   M_HARM    21                             Bridge Pier or Support   0.0291
# 5   M_HARM    42                               Tree (Standing Only)   1.3646
# 6   M_HARM    32                                            Culvert   0.1496
# 7   M_HARM    35                                         Embankment   0.3237
# 8   M_HARM    19                                           Building   0.1416
# 9   M_HARM    46                             Traffic Signal Support   0.0545
# 10  M_HARM    39                                               Wall   0.1301
# 11  M_HARM    30                         Utility Pole/Light Support   0.9649
# 12  M_HARM     6                 Injured In Vehicle (Non-Collision)   0.0053
# 13  M_HARM    93                               Unknown Fixed Object   0.0218
# 14  M_HARM    20                    Impact Attenuator/Crash Cushion   0.0322
# 15  M_HARM    45                              Working Motor Vehicle   0.0210
# 16  M_HARM    23                     Bridge Rail (Includes parapet)   0.0603
# 17  M_HARM     3                     Immersion or Partial Immersion   0.0262
# 18  M_HARM    58                                             Ground   0.0238
# 19  M_HARM    52                                      Guardrail End   0.1059
# 20  M_HARM    34                                              Ditch   0.7241
# 21  M_HARM     2                                     Fire/Explosion   0.0839
# 22  M_HARM    25                           Concrete Traffic Barrier   0.4502
# 23  M_HARM    26                              Other Traffic Barrier   0.0333
# 24  M_HARM    24                                     Guardrail Face   0.6307
# 25  M_HARM    33                                               Curb   0.4045
# 26  M_HARM    31                       Post, Pole or Other Supports   0.1564
# 27  M_HARM    44  Pavement Surface Irregularity (Ruts, Potholes,...   0.0236
# 28  M_HARM    17                                            Boulder   0.0347
# 29  M_HARM    38                                              Fence   0.3211
# 30  M_HARM    41                                          Shrubbery   0.0302
# 31  M_HARM    43                                 Other Fixed Object   0.2359
# 32  M_HARM     7                                Other Non-Collision   0.0170
# 33  M_HARM    91                           Unknown Object Not Fixed   0.0158
# 34  M_HARM    40                                       Fire Hydrant   0.0705
# 35  M_HARM    48                                          Snow Bank   0.0105
# 36  M_HARM    57                                      Cable Barrier   0.1105
# 37  M_HARM    59                               Traffic Sign Support   0.2982
# 38  M_HARM    53                                           Mail Box   0.1794
# 39  M_HARM    12                         Motor Vehicle In-Transport  81.0472
# 40  M_HARM    14                               Parked Motor Vehicle   1.7975
# 41  M_HARM    16                           Thrown or Falling Object   0.0191
# 42  M_HARM    55     Motor Vehicle in Motion Outside the Trafficway   0.0032
# 43  M_HARM    49           Ridden Animal or Animal Drawn Conveyance   0.0065
# 44  M_HARM    18                           Other Object (not fixed)   0.2828
# 45  M_HARM    50                          Bridge Overhead Structure   0.0254
# 46  M_HARM    72   Cargo/Equipment Loss, Shift, or Damage [harmful]   0.0205
# 47  M_HARM    11                                        Live Animal   1.8620
# 48  M_HARM    73  Object That Had Fallen From Motor Vehicle In-T...   0.0215
# 49  M_HARM    54  Motor Vehicle In-Transport Strikes or is Struc...   0.5307
# 50  M_HARM    51                Jackknife (harmful to this vehicle)   0.0365
# 51  M_HARM     8                                         Pedestrian   2.4443
# 52  M_HARM    15                Non-Motorist on Personal Conveyance   0.1595
# 53  M_HARM     9                                       Pedalcyclist   1.6794
#
#        Corr
# 0   80.0000
# 1   58.4615
# 2   53.6330
# 3   52.7820
# 4   49.4444
# 5   46.8854
# 6   42.4406
# 7   37.5936
# 8   37.4429
# 9   36.2018
# 10  34.2857
# 11  34.0312
# 12  33.3333
# 13  32.5926
# 14  31.1558
# 15  30.7692
# 16  30.5630
# 17  29.6296
# 18  29.2517
# 19  29.1603
# 20  29.1006
# 21  28.9017
# 22  27.3151
# 23  27.1845
# 24  26.6974
# 25  26.5282
# 26  24.2769
# 27  23.2877
# 28  21.8605
# 29  21.5903
# 30  20.8556
# 31  20.0685
# 32  19.0476
# 33  16.3265
# 34  15.8257
# 35  15.3846
# 36  14.7661
# 37  14.5257
# 38  12.7928
# 39  12.6293
# 40  11.3728
# 41  10.1695
# 42  10.0000
# 43  10.0000
# 44   8.7429
# 45   7.6433
# 46   5.5118
# 47   4.9557
# 48   4.5113
# 49   3.5018
# 50   2.2124
# 51   1.1967
# 52   0.8105
# 53   0.3849
#     feature = 'MAK_MOD'
#     A = [
#         ['0', [6010,76733,72704,71705,22001,43399,50031,2401,74706,30441,53702,71709,34705,99705,7017,20013,50709,99707,37733,37704,76709,20988,37702,53709,3884,12012,37709,73709,76703,98709,72709,98703,53705,98701,73704,76705,53706,58034,37706,98705,72706,73706,37703,76706,34709,50706,53734,73734,98706,73705,53704,76704,98704,37705,73703,53401,98702,50799,76701,99709,34706,77706,76702,71706,37739,37701,50705,76734,74705,53703,41401,42040,98733,99703,55032,98707,7470,9499,42053,69039,32054,38399,9037,99701,72705,93989,64031,73702,19006,76998,69038,6017,49055,7011,98734,20017,7004,55046,76739,22499,30032,35398,20038,20019,35053,74709,12008,94999,50399,12882,36398,31399,19027,12989,98907,42033,77709,12018,32047,21020,36399,41047,12998,13403,18402,14499,12015,52035,24008,69042,24002,54032,53999,59043,49441,22009,22023,19017,37734,24441,92989,12403,21017,98739,18003,22398,53036,2431,6398,21005,9019,10041,19019,23988,69398,69399,84998,45044,6444,42406,52040,7481,63035,67037,67399,65031,14037,49041,37035,48046,98982,13422,21002,35034,39036,54031,9038,14020,35056,52401,7898,20402,52471,52039,9442,55499,13482,52048,39032,20016,21441,21023,51051,6041,18441,39399,65399,53033,24003,20441,12013,20989,63498,55399,54499,13017,20471,41056,35404,63499,52399,12443,6052,20022,39035,2402,41044,20015,49398,38883,63403,19025,34703,63041,30399,13012,24001,19399,18401,55421,52999,54999,42031,20020,20004,18499,52403,35399,18026,55037,6044,7020,53034,6043,13002,6499,18399,12004,12032,49471,14443,20029,41402,67036,12424,20444,47036,42870,39038,34045,22032,7043,67033,59421,23471,34037,58499,25401,13401,47401,12399,63399,22403,36401,35050,37399,20443,35032,7444,20401,58043,41045,35471,20405,63037,22002,18025,20399,13005,63038,37033,22441,9020,62405,3499,52402,12016,12471,22016,37499,23401,35499,98398,14017,45040,14036,53499,7399,18019,63032,63033,35999,18002,63031,49399,52404,13999,20498,21021,14399,48044,14004,20406,20039,6018,35043,13399,42399,22018,14444,38401,18405,49050,62401,41499,35048,58038,12021,20009,41035,20403,53040,24006,55441,12006,7498,19021,38421,51040,34038,45037,12441,99739,23883,58398,55403,22010,53739,89881,73739,32421,20036,12035,49044,49048,24009,14038,55045,55036,7025,20027,42423,52046,12037,18022,51399,20023,35039,14401,55422,19003,55042,]], #  20.071 %
#         ['1', [49051,14006,32059,20032,18007,63999,24007,59399,38402,55035,41399,22999,92988,30999,13001,7021,53399,21003,51042,51499,51039,24499,20037,12442,49033,22019,6999,53035,20002,22020,22022,18020,18023,22399,54037,30051,12003,52037,53405,35403,6042,20010,20007,24399,39031,49405,19422,20025,18404,7029,41037,55999,49049,55404,2408,35047,12017,62424,23441,42499,6421,42405,6054,21399,63398,42045,94989,58399,35402,37031,34399,49032,62499,41055,12473,58037,98998,12402,20404,7404,84983,2405,19431,2499,7402,20028,14021,54038,23431,52034,24999,58999,63034,]], #  19.9417 %
#         ['2', [49999,52047,49043,30047,23399,12025,22401,20431,6442,42055,7471,38405,2482,32403,24011,22005,19401,18010,49034,55044,7039,51404,12425,42057,7024,51046,42043,7027,53404,7026,6051,34034,58042,30040,37039,35052,20445,12401,7472,58404,41049,37041,59033,2001,34999,34039,49040,23999,35051,41050,49056,6399,37032,55033,7461,24401,32999,12499,58032,12023,7442,54041,49499,35446,23402,19018,2407,49404,13015,23472,69054,20499,36038,59401,12027,63401,21401,7041,20999,20470,51034,99988,21022,3421,41471,24005,47035,59999,7499,19005,12422,54036,42042,37999,2404,]], #  20.9377 %
#         ['3', [37402,58036,55402,19024,63402,19026,14402,49481,67035,7403,41999,12999,12444,48499,67032,51047,2406,20482,23423,39034,49046,13402,59031,35049,12498,34048,51049,22008,48999,18018,14003,45401,49035,12981,69035,6441,13013,42403,53402,63036,12024,49401,32399,54399,37404,35422,42401,45399,19421,54035,42999,34404,37422,2483,20473,7028,48401,35401,34402,34403,55401,42048,51043,35443,51045,38471,12988,58039,30042,49402,23481,41051,20423,20421,36402,49403,3431,30046,35472,39401,59405,35473,52472,51401,54044,37401,37471,59035,19480,59034,49052,12022,42044,19020,20481,49038,63039,49442,49472,30402,37403,63441,48399,21001,21999,32044,63040,30499,2403,23421,67031,48034,35481,7422,23499,58035,19022,54421,19023,48421,]], #  19.0517 %
# ...
# 9   VEVENT_IM    46                             Traffic Signal Support
# 10  VEVENT_IM    39                                               Wall
# 11  VEVENT_IM    30                         Utility Pole/Light Support
# 12  VEVENT_IM     4                                     Gas Inhalation
# 13  VEVENT_IM    93                               Unknown Fixed Object
# 14  VEVENT_IM    20                    Impact Attenuator/Crash Cushion
# 15  VEVENT_IM     3                     Immersion or Partial Immersion
# 16  VEVENT_IM    45                              Working Motor Vehicle
# 17  VEVENT_IM    23                     Bridge Rail (Includes parapet)
# 18  VEVENT_IM    58                                             Ground
# 19  VEVENT_IM    52                                      Guardrail End
# 20  VEVENT_IM     2                                     Fire/Explosion
# 21  VEVENT_IM    34                                              Ditch
# 22  VEVENT_IM     6                 Injured In Vehicle (Non-Collision)
# 23  VEVENT_IM    25                           Concrete Traffic Barrier
# 24  VEVENT_IM    26                              Other Traffic Barrier
# 25  VEVENT_IM    24                                     Guardrail Face
# 26  VEVENT_IM    33                                               Curb
# 27  VEVENT_IM    31                       Post, Pole or Other Supports
# 28  VEVENT_IM    44  Pavement Surface Irregularity (Ruts, Potholes,...
# 29  VEVENT_IM    38                                              Fence
# 30  VEVENT_IM    17                                            Boulder
# 31  VEVENT_IM    41                                          Shrubbery
# 32  VEVENT_IM    43                                 Other Fixed Object
# 33  VEVENT_IM     7                                Other Non-Collision
# 34  VEVENT_IM    91                           Unknown Object Not Fixed
# 35  VEVENT_IM    40                                       Fire Hydrant
# 36  VEVENT_IM    48                                          Snow Bank
# 37  VEVENT_IM    57                                      Cable Barrier
# 38  VEVENT_IM    59                               Traffic Sign Support
# 39  VEVENT_IM    53                                           Mail Box
# 40  VEVENT_IM    12                         Motor Vehicle In-Transport
# 41  VEVENT_IM    49           Ridden Animal or Animal Drawn Conveyance
# 42  VEVENT_IM    16                           Thrown or Falling Object
# 43  VEVENT_IM    14                               Parked Motor Vehicle
# 44  VEVENT_IM    55     Motor Vehicle in Motion Outside the Trafficway
# 45  VEVENT_IM    18                           Other Object (not fixed)
# 46  VEVENT_IM    50                          Bridge Overhead Structure
# 47  VEVENT_IM    72   Cargo/Equipment Loss, Shift, or Damage [harmful]
# 48  VEVENT_IM    11                                        Live Animal
# 49  VEVENT_IM    73  Object That Had Fallen From Motor Vehicle In-T...
# 50  VEVENT_IM    54  Motor Vehicle In-Transport Strikes or is Struc...
# 51  VEVENT_IM    51                Jackknife (harmful to this vehicle)
# 52  VEVENT_IM     8                                         Pedestrian
# 53  VEVENT_IM    15                Non-Motorist on Personal Conveyance
# 54  VEVENT_IM     9                                       Pedalcyclist
#
#         Per     Corr
# 0    0.0008  80.0000
# 1    0.0120  55.4054
# 2    2.6590  53.6330
# 3    0.1081  52.6158
# 4    0.0291  49.4444
# 5    1.3644  46.8979
# 6    0.1509  42.2912
# 7    0.1423  37.4574
# 8    0.3266  37.3887
# 9    0.0546  36.0947
# 10   0.1309  34.3210
# 11   0.9680  33.9453
# 12   0.0005  33.3333
# 13   0.0218  32.5926
# 14   0.0323  31.5000
# 15   0.0270  30.5389
# 16   0.0212  30.5344
# 17   0.0614  30.2632
# 18   0.0237  29.2517
# 19   0.1058  29.1603
# 20   0.0840  29.0385
# 21   0.7266  29.0351
# 22   0.0061  28.9474
# 23   0.4509  27.4095
# 24   0.0338  27.2727
# 25   0.6313  26.6888
# 26   0.4064  26.4706
# 27   0.1586  24.6436
# 28   0.0236  23.2877
# 29   0.3218  21.5863
# 30   0.0355  21.3636
# 31   0.0305  20.6349
# 32   0.2363  20.1640
# 33   0.0173  19.6262
# 34   0.0158  16.3265
# 35   0.0714  15.8371
# 36   0.0107  15.1515
# 37   0.1105  14.7661
# 38   0.2980  14.5257
# 39   0.1793  12.7928
# 40  81.0178  12.6292
# 41   0.0066  12.1951
# 42   0.0195  11.5702
# 43   1.7980  11.3836
# 44   0.0032  10.0000
# 45   0.2833   8.7799
# 46   0.0254   7.6433
# 47   0.0205   5.5118
# 48   1.8636   4.9931
# 49   0.0215   4.5113
# 50   0.5305   3.5018
# 51   0.0365   2.2124
# 52   2.4446   1.2159
# 53   0.1601   0.8073
# 54   1.6799   0.4039
#     feature = 'VNUM_LAN'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [2,]], #  44.9531 %
#         ['2', []], #  0.0 %
#         ['3', [4,]], #  14.8614 %
#         ['4', []], #  0.0 %
#         ['5', [3,]], #  18.2764 %
#         ['6', []], #  0.0 %
#         ['7', [5,]], #  10.9793 %
#         ['8', [7,1,6,0,]], #  10.9298 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                               Name      Per     Corr
# 0  VNUM_LAN     2                          Two lanes  44.9531  18.2950
# 1  VNUM_LAN     4                         Four lanes  14.8614  13.6266
# 2  VNUM_LAN     3                        Three lanes  18.2764  13.4413
# 3  VNUM_LAN     5                         Five lanes  10.9793  13.3228
# 4  VNUM_LAN     7                Seven or more lanes   1.3722  11.7972
# 5  VNUM_LAN     1                           One lane   2.3721  11.2615
# 6  VNUM_LAN     6                          Six lanes   3.7086  11.0750
# 7  VNUM_LAN     0  Non-Trafficway or Driveway Access   3.4769   7.5867
#     feature = 'VPROFILE'
#     A = [
#         ['0', [6,5,4,3,]], #  5.9771 %
#         ['1', [1,]], #  83.0272 %
#         ['2', [2,0,]], #  10.9956 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                               Name      Per     Corr
# 0  VPROFILE     6                           Downhill   2.5991  22.7381
# 1  VPROFILE     5                             Uphill   1.9644  21.2952
# 2  VPROFILE     4                       Sag (Bottom)   0.1796  20.7292
# 3  VPROFILE     3                          Hillcrest   1.2340  19.7999
# 4  VPROFILE     1                              Level  83.0272  14.3376
# 5  VPROFILE     2               Grade, Unknown Slope   8.0784  14.2725
# 6  VPROFILE     0  Non-Trafficway or Driveway Access   2.9172   7.5867
#     feature = 'VSPD_LIM'
#     A = [
#         ['0', [90,]], #  0.0002 %
#         ['1', [55,]], #  10.9312 %
#         ['2', [80,75,70,50,]], #  14.7318 %
#         ['3', [65,]], #  0.0 %
#         ['4', [45,]], #  21.5203 %
#         ['5', [60,]], #  1.9729 %
#         ['6', [40,]], #  11.2788 %
#         ['7', []], #  0.0 %
#         ['8', [35,]], #  19.1915 %
#         ['9', []], #  9.1917 %
#         ['10', [25,30,20,15,0,10,5,]], #  11.1816 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code                                               Name  \
# 0   VSPD_LIM    90                                             90 MPH
# 1   VSPD_LIM    55                                             55 MPH
# 2   VSPD_LIM    80                                             80 MPH
# 3   VSPD_LIM    75                                             75 MPH
# 4   VSPD_LIM    70                                             70 MPH
# 5   VSPD_LIM    50                                             50 MPH
# 6   VSPD_LIM    65                                             65 MPH
# 7   VSPD_LIM    45                                             45 MPH
# 8   VSPD_LIM    60                                             60 MPH
# 9   VSPD_LIM    40                                             40 MPH
# 10  VSPD_LIM    35                                             35 MPH
# 11  VSPD_LIM    25                                             25 MPH
# 12  VSPD_LIM    30                                             30 MPH
# 13  VSPD_LIM    20                                             20 MPH
# 14  VSPD_LIM    15                                             15 MPH
# 15  VSPD_LIM     0  No Statutory Limit/Non-Trafficway or Driveway ...
# 16  VSPD_LIM    10                                             10 MPH
# 17  VSPD_LIM     5                                              5 MPH
#
#         Per      Corr
# 0    0.0002  100.0000
# 1   10.9312   21.4367
# 2    0.1461   19.7957
# 3    0.3286   18.6258
# 4    5.0208   17.8145
# 5    3.5611   17.7435
# 6    5.6752   16.1712
# 7   21.5203   14.8403
# 8    1.9729   14.5100
# 9   11.2788   13.4878
# 10  19.1915   12.9966
# 11   9.1917   10.9205
# 12   6.7770   10.6757
# 13   0.6184    8.9620
# 14   0.5623    7.6336
# 15   2.9593    7.5924
# 16   0.1877    5.4672
# 17   0.0769    5.3398
#     feature = 'VSURCOND'
#     A = [
#         ['0', [5,11,7,8,6,]], #  0.2729 %
#         ['1', [1,]], #  81.6571 %
#         ['2', []], #  0.0 %
#         ['3', [2,]], #  13.4651 %
#         ['4', [10,4,3,0,]], #  4.6048 %
#         ['Unknowns', [98, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code                               Name      Per     Corr
# 0   VSURCOND     5                               Sand   0.0088  37.7358
# 1   VSURCOND    11                Mud, Dirt or Gravel   0.1017  27.6423
# 2   VSURCOND     7                                Oil   0.0043  26.9231
# 3   VSURCOND     8                              Other   0.0339  19.5122
# 4   VSURCOND     6         Water (Standing or Moving)   0.1242  15.5792
# 5   VSURCOND     1                                Dry  81.6571  14.6778
# 6   VSURCOND     2                                Wet  13.4651  14.5140
# 7   VSURCOND    10                              Slush   0.1816  13.2969
# 8   VSURCOND     4                          Ice/Frost   0.8036  12.9477
# 9   VSURCOND     3                               Snow   1.0404  10.9062
# 10  VSURCOND     0  Non-Trafficway or Driveway Access   2.5792   7.5867
#     feature = 'VTCONT_F'
#     A = [
#         ['0', [1,]], #  0.1033 %
#         ['1', [0,]], #  62.2729 %
#         ['2', [4,]], #  0.006 %
#         ['3', [3,]], #  37.5464 %
#         ['4', [2,]], #  0.0713 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                                               Name      Per  \
# 0  VTCONT_F     1                             Device Not Functioning   0.1033
# 1  VTCONT_F     0                                        No Controls  62.2729
# 2  VTCONT_F     4  Device Not Functioning or Device Functioning I...   0.0060
# 3  VTCONT_F     3                        Device Functioning Properly  37.5464
# 4  VTCONT_F     2          Device Functioning-Functioning Improperly   0.0713
#
#       Corr
# 0  17.2241
# 1  15.3471
# 2  14.2857
# 3  12.9294
# 4  12.3487
#     feature = 'VTRAFCON'
#     A = [
#         ['0', [29,40,28,9,4,98,65,]], #  2.0442 %
#         ['1', [0,]], #  62.2529 %
#         ['2', []], #  0.0 %
#         ['3', [3,]], #  24.9677 %
#         ['4', [1,20,7,8,23,50,2,21,]], #  10.7352 %
#         ['Unknowns', [97, 99, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#      Feature  Code                                               Name  \
# 0   VTRAFCON    29                            Unknown Regulatory Sign
# 1   VTRAFCON    40                                       Warning Sign
# 2   VTRAFCON    28                              Other Regulatory Sign
# 3   VTRAFCON     9                     Unknown Highway Traffic Signal
# 4   VTRAFCON     4                    Flashing Traffic Control Signal
# 5   VTRAFCON    98                                              Other
# 6   VTRAFCON    65                            Railway Crossing Device
# 7   VTRAFCON     0                                        No Controls
# 8   VTRAFCON     3  Traffic control signal(on colors) not known wh...
# 9   VTRAFCON     1  Traffic control signal (on colors) without Ped...
# 10  VTRAFCON    20                                          Stop Sign
# 11  VTRAFCON     7                            Lane Use Control Signal
# 12  VTRAFCON     8                       Other Highway Traffic Signal
# 13  VTRAFCON    23                            School Zone Sign/Device
# 14  VTRAFCON    50                                             Person
# 15  VTRAFCON     2  Traffic control signal (on colors) with Pedest...
# 16  VTRAFCON    21                                         Yield Sign
#
#         Per     Corr
# 0    0.0047  25.9259
# 1    0.9904  21.4921
# 2    0.1326  19.7917
# 3    0.0086  18.0000
# 4    0.3094  17.6339
# 5    0.4713  17.1795
# 6    0.1272  15.8752
# 7   62.2529  15.3471
# 8   24.9677  12.9974
# 9    0.5316  12.9912
# 10   7.7977  12.7903
# 11   0.0508  12.5850
# 12   0.0656  10.5263
# 13   0.0432  10.0000
# 14   0.1293   9.3458
# 15   0.9955   8.1339
# 16   1.1215   5.8344
#     feature = 'VTRAFWAY'
#     A = [
#         ['0', []], #  0.0 %
#         ['1', [1,]], #  45.1904 %
#         ['2', []], #  0.0 %
#         ['3', [2,]], #  17.174 %
#         ['4', [5,]], #  5.757 %
#         ['5', [3,]], #  23.3378 %
#         ['6', [6,4,0,]], #  8.541 %
#         ['Unknowns', [8, 9, ]]
#     ]
#     data = Build_Individual_Feature_with_Dict(df_Veh, data, feature, A)
#     Feature  Code                                               Name      Per  \
# 0  VTRAFWAY     1                               Two-Way, Not Divided  45.1904
# 1  VTRAFWAY     2               Two-Way, Divided, Unprotected Median  17.1740
# 2  VTRAFWAY     5  Two-Way, Not Divided With a Continuous Left-Tu...   5.7570
# 3  VTRAFWAY     3        Two-Way,  Divided, Positive  Median Barrier  23.3378
# 4  VTRAFWAY     6                                 Entrance/Exit Ramp   2.6355
# 5  VTRAFWAY     4                                 One-Way Trafficway   2.8350
# 6  VTRAFWAY     0                  Non-Trafficway or Driveway Access   3.0705
#
#       Corr
# 0  16.8750
# 1  14.4629
# 2  14.3864
# 3  14.0477
# 4  11.1775
# 5  10.1202
# 6   7.5867
#         Feature  Code                           Name      Per   Corr
# 0      HOSPITAL     0  Not Transported for Treatment  14.4076  100.0
# 1      HOSPITAL     1                        EMS Air  14.4076  100.0
# 2     BDYTYP_IM    86                             86   0.0002  100.0
# 3      BODY_TYP    86                             86   0.0002  100.0
# 4       MAK_MOD  6010                           6010   0.0003  100.0
# ...         ...   ...                            ...      ...    ...
# 2509    TRAV_SP   101                            101   0.0003    0.0
# 2510    TRAV_SP   150                        150 MPH   0.0010    0.0
# 2511    TRAV_SP   139                            139   0.0003    0.0
# 2512    TRAV_SP   104                        104 MPH   0.0003    0.0
# 2513    TRAV_SP   125                        125 MPH   0.0010    0.0
#
# [2514 rows x 5 columns]
#
#         Feature  Code                           Name      Per      Corr
# 0      HOSPITAL     0  Not Transported for Treatment  14.4076  100.0000
# 1      HOSPITAL     1                        EMS Air  14.4076  100.0000
# 35     MAX_VSEV     3   Suspected Serious Injury (A)   6.3571   78.5422
# 37    MXVSEV_IM     3   Suspected Serious Injury (A)   6.3412   76.5349
# 75        MODEL   709                            709   0.5147   64.5009
# ...         ...   ...                            ...      ...       ...
# 2137     M_HARM     9                   Pedalcyclist   1.6794    0.3849
# 2141   NUM_INJV     0   No Person Injured in Vehicle  65.4842    0.0092
# 2142   MAX_VSEV     0         No Apparent Injury (O)  65.4815    0.0069
# 2143  NUMINJ_IM     0   No Person Injured in Vehicle  65.4369    0.0025
# 2466  MXVSEV_IM     0         No Apparent Injury (O)  65.4333    0.0000
#
# [524 rows x 5 columns]
